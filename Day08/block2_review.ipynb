# %% [markdown]
# commonly used - object, classes, etc.
# weaknesses/needs work -while loops, functions, logic
# topics in core that are not tackled in-depth like lists, etc.

# %%
# Remove all names that contain numbers or are too short
students = ["Alice", "Bob123", "Kai", "Z3n", "Luna", "A"]

# Output: ['Alice', 'Luna']

#list comprehension
filtered = [item for item in students if not any(char.isdigit() for char in item) and len(item) > 3]

print(filtered)

# beginner

list_2 = []


for word in students:
    has_digit = False

    for char in word:
        if char.isdigit():
            has_digit = True
            break

    if not has_digit and len(word) > 3:
        list_2.append(word)

print(list_2)
# Out:
# ['Alice', 'Luna']
# ['Alice', 'Luna']

# %% [markdown]
# ---
#
# ## 🧩 **Challenge: Clean the Usernames!**
#
# ### 📜 Scenario:
#
# You're building a user registration system. You receive a raw list of submitted usernames, but not all of them are valid.
#
# ### ✅ **Rules for Valid Usernames:**
#
# 1. Must be **at least 5 characters long**.
# 2. Must **not contain any digits**.
# 3. Must be **all lowercase**.
#
# ---
#
# ### 🧠 Task:
#
# Write a program that takes this list:
#
# ```python
# usernames = [
#     "admin", "Guest123", "john", "alice", "eve99", "root42",
#     "Zoey", "charlie", "b0bby", "delta", "gamma1", "lambda"
# ]
# ```
#
# And produces a new list:
#
# ```python
# valid_usernames = [...]  # only those that follow all 3 rules
# ```
#
# ### 🧪 Expected Output:
#
# ```python
# ['admin', 'alice', 'charlie', 'delta', 'lambda']
# ```
#
# ---
#
# ## ✍️ Bonus:
#
# * Try solving it **first using a `for` loop + append**.
# * Then try rewriting it as a **list comprehension**.
#
# ---

# %%
usernames = [
    "admin", "Guest123", "john", "alice", "eve99", "root42",
    "Zoey", "charlie", "b0bby", "delta", "gamma1", "lambda"
]

valid_usernames = []

# using for loop + append

for word in usernames:
    has_digit = False

    for char in word:
        if char.isdigit():
            has_digit = True
            break #stops as soon as we know the answer
    
    if not has_digit:
        valid_usernames.append(word)

print(valid_usernames)


#list comprehension

filtered = [word for word in usernames if not any(char.isdigit() for char in word)]
print(filtered)
# Out:
# ['admin', 'john', 'alice', 'Zoey', 'charlie', 'delta', 'lambda']
# ['admin', 'john', 'alice', 'Zoey', 'charlie', 'delta', 'lambda']

# %% [markdown]
# 🎒 **RPG Inventory Manager**
#
# Start with:
#
# ```python
# inventory = ["sword", "potion", "potion", "dagger", "scroll", "potion"]
# ```
#
# Tasks:
#
# - Count how many potions
#
# - Remove all potions
#
# - Add a new item `"amulet"` to the start
#
# - Print inventory in reverse
#
#
# ✔️ Use: `.count()`, `.remove()`, `.insert()`, slicing

# %%
inventory = ["sword", "potion", "potion", "dagger", "scroll", "potion"]

#count how many potions
print(inventory.count("potion"))

#Remove all potions
for item in inventory:
    inventory.remove("potion")

print(inventory)

# Add a new item `"amulet"` to the start
inventory.append("amulet")
print(inventory)

#Print inventory in reverse
inventory.reverse()
print(inventory)
# Out:
# 3
# ['sword', 'dagger', 'scroll']
# ['sword', 'dagger', 'scroll', 'amulet']
# ['amulet', 'scroll', 'dagger', 'sword']

# %% [markdown]
# 🧠 **Stat Upgrades**
#
# ```python
# stats = [10, 15, 12, 8, 20]  # STR, DEX, INT, WIS, CHA
# ```
#
# - Add +2 to all stats using list comprehension
#
# - Remove the weakest stat
#
# - Print the average stat (sum / len)

# %%
stats = [10, 15, 12, 8, 20] 

# - Add +2 to all stats using list comprehension
upgrade = [stat + 2 for stat in stats]
print(upgrade)

# - Remove the weakest stat

min_stat = min(stats)
weakest = [stat for stat in stats if stat != min_stat]
print(weakest)

stats.remove(min(stats))
print(stats)

# Print the average stat (sum / len)
print(sum(stats)/ len(stats))
# Out:
# [12, 17, 14, 10, 22]
# [10, 15, 12, 20]
# [10, 15, 12, 20]
# 14.25

# %% [markdown]
# **List of Dicts — Inventory 2.0**
#
# ```python
# inventory = [
#     {"item": "potion", "qty": 2},
#     {"item": "scroll", "qty": 1},
#     {"item": "dagger", "qty": 3}
# ]
# ```
#
# Tasks:
#
# - Find total quantity of all items
#
# - Increase potion qty by 1
#
# - Remove all daggers
#
# - Print: `"You have 3 potions, 1 scroll"`
#
#
# ✔️ Requires: loops, conditionals, list modification

# %%
inventory = [
    {"item": "potion", "qty": 2},
    {"item": "scroll", "qty": 1},
    {"item": "dagger", "qty": 3}
]

# Find total quantity of all items

for item in inventory:
    qty = sum(item['qty'] for item in inventory)

print(qty)

# Increase potion qty by 1
for item in inventory:
    item['qty'] += 1
    print(item)


# - Remove all daggers
for item in inventory:
    if item['item'] == 'dagger':
        inventory.remove(item)
print(inventory)

#list comprehension

new_inventory = [item for item in inventory if item['item'] != 'dagger']
print(new_inventory)
# Out:
# 6
# {'item': 'potion', 'qty': 3}
# {'item': 'scroll', 'qty': 2}
# {'item': 'dagger', 'qty': 4}
# [{'item': 'potion', 'qty': 3}, {'item': 'scroll', 'qty': 2}]
# [{'item': 'potion', 'qty': 3}, {'item': 'scroll', 'qty': 2}]
# You have

# %% [markdown]
# Love Calculator
# 💪 This is a difficult challenge! 💪 (From App Brewery)
#
# You are going to write a function called calculate_love_score() that tests the compatibility between two names.  To work out the love score between two people:
#
# 1. Take both people's names and check for the number of times the letters in the word TRUE occurs.
#
# 2. Then check for the number of times the letters in the word LOVE occurs.
#
# 3. Then combine these numbers to make a 2 digit number and print it out.
#
# e.g.
#
# name1 = "Angela Yu" name2 = "Jack Bauer"
#
# T occurs 0 times
#
# R occurs 1 time
#
# U occurs 2 times
#
# E occurs 2 times
#
# Total = 5
#
# L occurs 1 time
#
# O occurs 0 times
#
# V occurs 0 times
#
# E occurs 2 times
#
# Total = 3
#
# Love Score = 53
#
# Example Input
#
# calculate_love_score("Kanye West", "Kim Kardashian")
#
# Example Output
#
# 42

# %%
def calculate_love_score(name1, name2):
    combined = (name1 + name2).lower()
    total_true = sum(combined.count(char) for char in 'true')
    total_love = sum(combined.count(char) for char in 'love')
    

    print(f"{total_true}{total_love}")
    

calculate_love_score("Kanye West", "Kim Kardashian")
# Out:
# 42

# %% [markdown]
# **Stage 1 – String Processing**
# Goal: Train you to see built-in methods before loops.

# %%
import string
word = "encyclopedia"
vowel_count = sum(word.count(char) for char in 'aeiou')
print(vowel_count)

# Check if a string is a palindrome
# "racecar" → True, "python" → False

word1 = 'racecar'
word2 = 'python'

def is_palindrome(word):
    return word == word[::-1]

print(is_palindrome("racecar"))
print(is_palindrome("python"))

# Check if "A man a plan a canal Panama" is a palindrome.

def palindrome(sentence):
    sentence_clean = sentence.replace(" ", "").lower()
    return sentence_clean == sentence_clean[::-1]

sentence = palindrome("A man a plan a canal Panama")
print(sentence)

# Write a version that ignores punctuation and numbers.
def no_punctuation(sentence):
    clean = sentence.replace(" ", "").lower()
    remove = "".join(char for char in clean if char not in string.punctuation)
    return remove == remove[::-1]

sentence2 = no_punctuation("Sore, was I ere I saw Eros.")
print(sentence2)

# Count how many palindromes are in a list:

palindrome = ["racecar", "madam", "apple", "noon"]

palindrome_new = sum(palindrome.count(word) for word in palindrome if word == word[::-1])

print(palindrome_new)

palindrome_2 = sum(1 for word in palindrome if word == word[::-1]) #recommended, only goes through the list once

print(palindrome_2)

# Remove all spaces from a sentence
# "this is a test" → "thisisatest"

sentence = "this is a test"

remove_space = sentence.replace(" ", "")
print(remove_space)

# Replace all numbers in a string with #
# "p4ssw0rd" → "p#ssw#rd"

numbers_word = "p4ssw0rd"
word_new = ''.join(['#' if char.isdigit() else char for char in numbers_word])
print(word_new)
# Out:
# 5
# True
# False
# True
# True
# 3
# 3
# thisisatest
# p#ssw#rd
